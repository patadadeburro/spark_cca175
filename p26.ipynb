# %% [markdown]
# # CCA175 Practice Exam
# * Exam    : CCA175
# * Title   : CCA Spark and Hadoop Developer Exam
# * Vendor  : Cloudera
# * Version : V12.35
#
# IT Certification Guaranteed, The Easy Way!

# %% [markdown]
# ## NO.26 CORRECT TEXT
# ### Problem Scenario 14 :
#
# You have been given following mysql database details as well as other info.
#
# | attribute | value|
# |-|-|
# | user      | retail_dba
# | password  | cloudera
# | database  | retail_db
# | jdbc URL  |  jdbc:mysql://quickstart:3306/retail_db
#
# Please accomplish following activities.

# %% [markdown]
# 1 . Create a csv file named `updated_departments.csv` with the following contents in local file system.

# %%
2,fitness
3,footwear
12,fathematics
13,fcience
14,engineering
1000,management

# %% [markdown]
# 2 . Upload this csv file to hdfs filesystem,

# %% [markdown]
# 3 . Now export this data from hdfs to mysql `retaildb.departments` table.
#
# During upload make sure existing department will just updated and new departments needs to be inserted.

# %% [markdown]
# 4 . Now update `updated_departments.csv` file with below content.

# %%
2,Fitness
3,Footwear
12,Fathematics
13,Science
14,Engineering
1000,Management
2000,Quality Check

# %% [markdown]
# 5 . Now upload this file to hdfs.

# %% [markdown]
# 6 . Now export this data from hdfs to mysql `retail_db.departments` table.
#
# During upload make sure existing department will just updated and no new departments needs to be inserted.

# %% [markdown]
# #### Answer

# %% [markdown]
# #### activity 2
# Upload this csv file to hdfs filesystem

# %%
hdfs dfs -mkdir /user/cloudera/p26

hdfs dfs -put updated_departments.csv /user/cloudera/p26

# %% [markdown]
# #### Activity 3.
# Now export this data from hdfs to mysql `retaildb.departments` table.
# During upload make sure existing department will just updated and new departments needs to be inserted.

# %%
sqoop export
--connect    jdbc:mysql://quickstart:3306/retail_db
--username=retail_dba
--password=cloudera
--table      departments
--update-key department_id
--update-mode allowinsert
--export-dir /user/cloudera/p26/updated_departments.csv

# %%
sqoop export --connect    jdbc:mysql://quickstart:3306/retail_db --username=retail_dba --password=cloudera --table      departments --update-key department_id --update-mode allowinsert --export-dir /user/cloudera/p26/updated_departments.csv

# %%
sqoop export
--connect    jdbc:mysql://quickstart:3306/retail_db
--username=retail_dba
--password=cloudera
--table      departments
--update-key department_id
--update-mode updateonly
--export-dir /user/cloudera/p26/updated_departments.csv
